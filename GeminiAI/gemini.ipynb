# %% [markdown]
# ## Gemini AI Project

# %%
import os
os.environ['GEMINI_API_KEY'] = 'AIzaSyDQuJFVET3dMD0ilgAdoTMChsQJ8y0o5A8'

# %%
# pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~oogle-ai-generativelanguage (c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~oogle-ai-generativelanguage (c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~oogle-ai-generativelanguage (c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['GEMINI_API_KEY'])

# %%
# model = genai.GenerativeModel('models/gemini-2.5-flash-lite-preview-06-17')

model = genai.GenerativeModel('models/gemini-2.5-flash-preview-09-2025')

# model = genai.GenerativeModel('models/gemini-2.5-computer-use-preview-10-2025')

# %%
response = model.generate_content("tabular format of the answer difference between ai vs ml vs genai")
print(response.text)
# Out:
# ## AI vs. ML vs. GenAI: Key Differences
#
# | Feature | Artificial Intelligence (AI) | Machine Learning (ML) | Generative AI (GenAI) |
# | :--- | :--- | :--- | :--- |
# | **Definition** | The broad field of creating systems that can simulate human intelligence. | A subset of AI focused on building algorithms that allow machines to learn from data without explicit programming. | A specific subset of ML (and therefore AI) focused on creating novel and realistic content (data, images, text, etc.). |
# | **Scope** | Broadest (encompasses everything from expert systems to robotics). | Medium (a major approach within AI). | Narrowest (a specific capability within ML/AI). |
# | **Goal** | To create intelligent systems capable of solving complex problems and acting rationally. | To enable systems to learn patterns and make predictions or decisions based on input data. | To generate new, original, and high-quality outputs that resemble real-world content. |
# ...

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# ...

# %%
# %%time
response = model.generate_content("create a table for summarize to a kid about AI vs Genai")
# Out:
# CPU times: total: 0 ns
# Wall time: 2.69 s

# %%
to_markdown(response.text)
# Out:
# > Here is a fun and easy table to explain AI vs. GenAI to a kid!
# >
# > | Feature | 🤖 **AI (Artificial Intelligence)** | ✨ **GenAI (Generative AI)** |
# > | :--- | :--- | :--- |
# > | **What it is** | A **Smart Robot Brain** that can learn and solve problems. | A **Creative Robot Artist** that makes new stuff. |
# > | **What it Tries to Do** | Be smart and make decisions (like knowing a cat from a dog). | Make brand new things (like drawing a picture of a cat). |
# > | **Examples of Work** | 🧠 Finding the fastest route on a map, guessing the weather. | 🖼️ Writing a story, drawing a picture, making a new song. |
# > | **How to Think of It** | **The Big Boss:** All smart programs are under this name. | **The Creative Helper:** A special part of the Big Boss that makes art. |
# > | **Key Question** | "What is the answer?" (Solving a problem) | "What can I create?" (Making something new) |
# ...

# %%
response.prompt_feedback

# %%
response.candidates
# Out:
# [content {
#   parts {
# ...

# %%
for chunk in response:
    print(chunk.text)
    # print("_"*5)
# Out:
# Here is a fun and easy table to explain AI vs. GenAI to a kid!
#
# | Feature | 🤖 **AI (Artificial Intelligence)** | ✨ **GenAI (Generative AI)** |
# | :--- | :--- | :--- |
# | **What it is** | A **Smart Robot Brain** that can learn and solve problems. | A **Creative Robot Artist** that makes new stuff. |
# | **What it Tries to Do** | Be smart and make decisions (like knowing a cat from a dog). | Make brand new things (like drawing a picture of a cat). |
# | **Examples of Work** | 🧠 Finding the fastest route on a map, guessing the weather. | 🖼️ Writing a story, drawing a picture, making a new song. |
# | **How to Think of It** | **The Big Boss:** All smart programs are under this name. | **The Creative Helper:** A special part of the Big Boss that makes art. |
# | **Key Question** | "What is the answer?" (Solving a problem) | "What can I create?" (Making something new) |
# ...

# %% [markdown]
# ## MultiModel

# %%
import PIL.Image
img = PIL.Image.open(r'C:\Users\sha2n\OneDrive\Pictures\imgo\aaa (25).jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1242x2208>

# %%
model = genai.GenerativeModel('models/gemini-2.5-flash-lite-preview-09-2025')

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
response = model.generate_content(img)
to_markdown(response.text)
# Out:
# > This is a stunning portrait, likely depicting an individual dressed up as the Hindu deity **Lord Krishna**.
# >
# > Here is a detailed description of the image:
# >
# > **Subject and Appearance:**
# > *   **Skin Tone:** The subject's face is painted a vibrant, deep shade of blue, characteristic of depictions of Krishna.
# > *   **Facial Markings (Tilak):** A white *Urdhva Pundra Tilak* (a sectarian mark) is prominently drawn on the forehead, signifying devotion.
# > *   **Expression:** The eyes are closed, conveying a serene, meditative, or deeply devotional mood. The lips are painted a soft reddish hue.
# > *   **Attire/Adornments:**
# >     *   **Headdress (Turban/Pagri):** The subject wears a richly textured, golden or mustard-yellow turban (pagri).
# >     *   **Head Ornamentation:** Tucked into the turban are several significant adornments:
# ...

# %%
response = model.generate_content(["Write a scripts for my youTube shorts to gain view", img], stream=True)
response.resolve()

# %%
to_markdown(response.text)
# Out:
# > This is a stunning image, perfect for a visually engaging YouTube Short! The deep colors, the focus, and the subject matter (Lord Krishna) lend themselves well to content that is both aesthetically pleasing and spiritually resonant.
# >
# > Here are **three distinct script options** for your YouTube Short, designed to maximize engagement:
# >
# > ---
# >
# > ## Option 1: The Aesthetic/Transformation Short (Focus on Visual Impact)
# >
# > This script is fast-paced and relies heavily on the powerful music and visual transformation (if you have a "before" shot, use it!).
# >
# > **Theme:** The Divine Aura
# > **Length:** 10–15 seconds
# > **Music Suggestion:** A modern, cinematic devotional track or an instrumental with heavy bass drops/build-up.
# >
# > | Time (Approx.) | Visual Action | Text/Voiceover (Keep text on screen for maximum impact) |
# > | :--- | :--- | :--- |
# ...
