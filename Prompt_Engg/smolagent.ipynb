# %%
# pip install smolagents
# Out:
# Collecting smolagents
#   Downloading smolagents-1.23.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.31.2 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from smolagents) (0.34.1)
# Requirement already satisfied: requests>=2.32.3 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from smolagents) (2.32.5)
# Requirement already satisfied: rich>=13.9.4 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from smolagents) (14.1.0)
# Requirement already satisfied: jinja2>=3.1.4 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from smolagents) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from smolagents) (11.3.0)
# Requirement already satisfied: python-dotenv in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from smolagents) (1.2.1)
# Requirement already satisfied: filelock in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (2025.7.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from jinja2>=3.1.4->smolagents) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.32.3->smolagents) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.32.3->smolagents) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.32.3->smolagents) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.32.3->smolagents) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from rich>=13.9.4->smolagents) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from rich>=13.9.4->smolagents) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents) (0.1.2)
# Requirement already satisfied: colorama in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0.0,>=0.31.2->smolagents) (0.4.6)
# Downloading smolagents-1.23.0-py3-none-any.whl (148 kB)
# Installing collected packages: smolagents
# Successfully installed smolagents-1.23.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~oogle-ai-generativelanguage (c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~oogle-ai-generativelanguage (c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~oogle-ai-generativelanguage (c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)

# %%
import os 
os.environ["HF_TOKEN"] = " "

# %%
# from smolagents import CodeAgent, DuckDuckGoSearchTool, HfApiModel
from smolagents import CodeAgent, DuckDuckGoSearchTool, TransformersModel

# %%
# !pip install duckduckgo-search 
# pip install smolagents[transformers]
# Out:
# Collecting duckduckgo-search
#   Downloading duckduckgo_search-8.1.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: click>=8.1.8 in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from duckduckgo-search) (8.1.8)
# Collecting primp>=0.15.0 (from duckduckgo-search)
#   Downloading primp-0.15.0-cp38-abi3-win_amd64.whl.metadata (13 kB)
# Collecting lxml>=5.3.0 (from duckduckgo-search)
#   Downloading lxml-6.0.2-cp313-cp313-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: colorama in c:\users\sha2n\appdata\local\programs\python\python313\lib\site-packages (from click>=8.1.8->duckduckgo-search) (0.4.6)
# Downloading duckduckgo_search-8.1.1-py3-none-any.whl (18 kB)
# Downloading lxml-6.0.2-cp313-cp313-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 2.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.0/4.0 MB 2.0 MB/s eta 0:00:02
#    ------------- -------------------------- 1.3/4.0 MB 1.9 MB/s eta 0:00:02
#    ------------------ --------------------- 1.8/4.0 MB 2.0 MB/s eta 0:00:02
#    -------------------------- ------------- 2.6/4.0 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/4.0 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 2.2 MB/s  0:00:01
# Downloading primp-0.15.0-cp38-abi3-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.8/3.1 MB 3.4 MB/s eta 0:00:01
#    ------------------- -------------------- 1.6/3.1 MB 3.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.4/3.1 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 3.8 MB/s  0:00:00
# Installing collected packages: primp, lxml, duckduckgo-search
#
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    -------------------------- ------------- 2/3 [duckduckgo-search]
#    -------------------------- ------------- 2/3 [duckduckgo-search]
#    ---------------------------------------- 3/3 [duckduckgo-search]
#
# Successfully installed duckduckgo-search-8.1.1 lxml-6.0.2 primp-0.15.0
# WARNING: Ignoring invalid distribution ~oogle-ai-generativelanguage (C:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~oogle-ai-generativelanguage (C:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~oogle-ai-generativelanguage (C:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages)

# %%
# model = HfApiModel()
model = TransformersModel()
agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=model)
# Out:
# c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages\smolagents\models.py:897: FutureWarning: The 'model_id' parameter will be required in version 2.0.0. Please update your code to pass this parameter to avoid future errors. For now, it defaults to 'HuggingFaceTB/SmolLM2-1.7B-Instruct'.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages\smolagents\models.py:913, in TransformersModel.__init__(self, model_id, device_map, torch_dtype, trust_remote_code, model_kwargs, max_new_tokens, max_tokens, **kwargs)
#     912 try:
# --> 913     self.model = AutoModelForImageTextToText.from_pretrained(
#     914         model_id,
#     915         device_map=device_map,
#     916         torch_dtype=torch_dtype,
#     917         trust_remote_code=trust_remote_code,
#     918         **self.model_kwargs,
#     919     )
#     920     self.processor = AutoProcessor.from_pretrained(model_id, trust_remote_code=trust_remote_code)
#
# File c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\models\auto\auto_factory.py:607, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     604     return model_class.from_pretrained(
#     605         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     606     )
# --> 607 raise ValueError(
#     608     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     609     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     610 )
#
# ValueError: Unrecognized configuration class <class 'transformers.models.llama.configuration_llama.LlamaConfig'> for this kind of AutoModel: AutoModelForImageTextToText.
# Model type should be one of AriaConfig, AyaVisionConfig, BlipConfig, Blip2Config, ChameleonConfig, Cohere2VisionConfig, DeepseekVLConfig, DeepseekVLHybridConfig, Emu3Config, EvollaConfig, Florence2Config, FuyuConfig, Gemma3Config, Gemma3nConfig, GitConfig, Glm4vConfig, Glm4vMoeConfig, GotOcr2Config, IdeficsConfig, Idefics2Config, Idefics3Config, InstructBlipConfig, InternVLConfig, JanusConfig, Kosmos2Config, Kosmos2_5Config, Llama4Config, LlavaConfig, LlavaNextConfig, LlavaNextVideoConfig, LlavaOnevisionConfig, Mistral3Config, MllamaConfig, Ovis2Config, PaliGemmaConfig, PerceptionLMConfig, Pix2StructConfig, PixtralVisionConfig, Qwen2_5_VLConfig, Qwen2VLConfig, ShieldGemma2Config, SmolVLMConfig, UdopConfig, VipLlavaConfig, VisionEncoderDecoderConfig.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 # model = HfApiModel()
# ----> 2 model = TransformersModel()
#       3 agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=model)
#
# File c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages\smolagents\models.py:926, in TransformersModel.__init__(self, model_id, device_map, torch_dtype, trust_remote_code, model_kwargs, max_new_tokens, max_tokens, **kwargs)
#     924 except ValueError as e:
#     925     if "Unrecognized configuration class" in str(e):
# --> 926         self.model = AutoModelForCausalLM.from_pretrained(
#     927             model_id,
#     928             device_map=device_map,
#     929             torch_dtype=torch_dtype,
#     930             trust_remote_code=trust_remote_code,
#     931             **self.model_kwargs,
#     932         )
#     933         self.tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=trust_remote_code)
#     934         self.streamer = TextIteratorStreamer(self.tokenizer, skip_prompt=True, skip_special_tokens=True)  # type: ignore
#
# File c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\models\auto\auto_factory.py:604, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     602     if model_class.config_class == config.sub_configs.get("text_config", None):
#     603         config = config.get_text_config()
# --> 604     return model_class.from_pretrained(
#     605         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     606     )
#     607 raise ValueError(
#     608     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     609     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     610 )
#
# File c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\modeling_utils.py:288, in restore_default_dtype.<locals>._wrapper(*args, **kwargs)
#     286 old_dtype = torch.get_default_dtype()
#     287 try:
# --> 288     return func(*args, **kwargs)
#     289 finally:
#     290     torch.set_default_dtype(old_dtype)
#
# File c:\Users\sha2n\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\modeling_utils.py:4936, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4934         raise ValueError("DeepSpeed Zero-3 is not compatible with passing a `device_map`.")
#    4935     if not is_accelerate_available():
# -> 4936         raise ValueError(
#    4937             "Using a `device_map`, `tp_plan`, `torch.device` context manager or setting `torch.set_default_device(device)` "
#    4938             "requires `accelerate`. You can install it with `pip install accelerate`"
#    4939         )
#    4941 # handling bnb config from kwargs, remove after `load_in_{4/8}bit` deprecation.
#    4942 if load_in_4bit or load_in_8bit:
#
# ValueError: Using a `device_map`, `tp_plan`, `torch.device` context manager or setting `torch.set_default_device(device)` requires `accelerate`. You can install it with `pip install accelerate`

# %%
agent.run('differential human brain & machine brain')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 agent.run('differential human brain & machine brain')
#
# NameError: name 'agent' is not defined
