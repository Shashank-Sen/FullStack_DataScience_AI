# %% [markdown]
# ### Image analysis using numpy

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image  # python imageing libraries

# %%
# img = Image.open(r'C:\Users\sha2n\OneDrive\Pictures\imgo\aaa (18).jpg')
# img

# %%
image = Image.open(r'C:\Users\sha2n\OneDrive\Pictures\imgo\sss (7).jpg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1053>
