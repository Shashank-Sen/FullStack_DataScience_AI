# %% [markdown]
# # Function in pythhon
# ### (22-07-25)

# %% [raw]
# 1- define the function
# 2- print the statement
# 3- call the function

# %% [raw]
# Functional Arguments can divided in 2 parts:
#   1- Formal Argument:
#   2- Actual Argument:
#     1- Positional Argument
#     2- keyword Argument
#     3- default Argument
#     4- variable length Argument

# %%
def greet(): # declare function without argument.
    print('Hello')
    print('Good morning')
greet()  # function calling
# Out:
# Hello
# Good morning

# %%
def greet(): # declare function without argument. 
    print('hello')
    print('good morning team')
greet()

def greet(): 
    print('hello')
    print('good morning team')
greet()
# Out:
# hello
# good morning team
# hello
# good morning team

# %%
def greet():  # declare function without argument
    print('hello')
    print('good morning team')
greet()
print('***********')
greet()
print('***********')
greet() # function calling  with out argument)
# Out:
# hello
# good morning team
# ***********
# hello
# good morning team
# ***********
# hello
# good morning team

# %%
# function with argument 

def add(x,y):
    c=x+y
    return c  
   
add(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       4     c=x+y
#       5     return c
# ----> 7 add(5)
#
# TypeError: add() missing 1 required positional argument: 'y'

# %%
# function with argument 
def add(x, y):  # Formal Argument
    z = x + y
    print(z)
add(10, 5) #  Actual Argument
# Out:
# 15

# %%
# function with argument 

def add(x,y):
    c=x+y
    return c  
   
add(5,6)
# Out:
# 11

# %%
# function with argument 

def add(x,y):
    c=x+y
    return c  
   
add(5,6,7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4     c=x+y
#       5     return c
# ----> 7 add(5,6,7)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
# function with argument 

def add(x,y,z):
    c=x+y
    return c  
   
add(5,6,7)
# Out:
# 11

# %%
# function with argument 

def add(x,y,z):
    c=x+y+z+m 
    return c  
   
add(5,6,7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 7
#       4     c=x+y+z+m
#       5     return c
# ----> 7 add(5,6,7)
#
# Cell In[13], line 4, in add(x, y, z)
#       3 def add(x,y,z):
# ----> 4     c=x+y+z+m
#       5     return c
#
# NameError: name 'm' is not defined

# %%
# function with argument 

def add(x,y,z,n):
    c = x+y+z+m 
    return c  
   
add(5,6,7,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 7
#       4     c = x+y+z+m
#       5     return c
# ----> 7 add(5,6,7,8)
#
# Cell In[14], line 4, in add(x, y, z, n)
#       3 def add(x,y,z,n):
# ----> 4     c = x+y+z+m
#       5     return c
#
# NameError: name 'm' is not defined

# %%
# function with argument 

def add(x,y,z,n):
    c = x+y+z+n
    return c  
   
add(5,6,7,8)
# Out:
# 26

# %%
# Define multiple functions at once.
def greet(): 
    print('hello')
    print('good morning team')
greet()

def add(x,y):
    c = x+y
    return c  
   
add(5,6)
# Out:
# hello
# good morning team
# 11

# %%
# Define multiple functions at once.
def greet(): 
    print('hello')
    print('good morning team')
    
def add(x,y):
    c = x+y
    return c  

def sub(x,y):
    d = x-y
    return d


greet()   
print(add(5,6))
print(sub(5,6))
# Out:
# hello
# good morning team
# 11
# -1

# %%
def add_sub(x,y): 
    c= x+y
    d= x-y
    return c, d 
    
result = add_sub(4,6)
print(result)
print(type(result))
# Out:
# (10, -2)
# <class 'tuple'>

# %%
def add_sub(x,y): 
    c= x+y
    d= x-y
    return c, d 
    
result, result1 = add_sub(4,5)

print(result)
print(result1)
print(type(result))
# Out:
# 9
# -1
# <class 'int'>

# %%
def add_sub_mul(x,y): 
    c= x+y
    d= x-y
    e= x*y
    return c, d, e 
    
add, sub, mul = add_sub_mul(4,5)

add
sub
mul
# Out:
# 20

# %% [markdown]
# # Update

# %%
def update(): 
    x = 8
    print(x)
update()
# Out:
# 8

# %%
def update(): #update function take the value from the user
    x = 8
    print(x)
    
update(8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       2     x = 8
#       3     print(x)
# ----> 5 update(8)
#
# TypeError: update() takes 0 positional arguments but 1 was given

# %%
def update(x): #update function take the value from the user
    x = 8
    return x
    
update(100)
# Out:
# 8

# %%
def update(x):  
    x = 8
    return x
    
a = 15
update(a)
print(a)
# Out:
# 15
